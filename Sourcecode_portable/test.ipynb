# %%
import pandas as pd
df = pd.read_table(
    'data_linear_elastic.txt', sep=",",header=None)
print(df)
# Out:
#          0                   1                   2  3  4     5   \
# 0         E                   v      element_length  Q  T     p
# 1     50000                 0.2  13.333333333333336  0  2  52.5
# 2     50000                 0.2  26.666666666666664  0  2  52.5
# 3     50000                 0.2  13.333333333333336  0  2    70
# 4     50000                 0.2  26.666666666666664  0  2    70
# ..      ...                 ...                 ... .. ..   ...
# 206  450000  0.4000000000000001  26.666666666666664  0  2    70
# 207  450000  0.4000000000000001  13.333333333333336  0  2    70
# 208  450000  0.4000000000000001  26.666666666666664  0  2    70
# 209  450000  0.4000000000000001  13.333333333333336  0  2    70
# 210  450000  0.4000000000000001  26.666666666666664  0  2    70
#
#                   6                  7         8         9   \
# 0           f_int[0]           f_int[1]  f_ext[0]  f_ext[1]
# 1               [0.]               [0.]   [2100.]      [0.]
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df.loc[1:,8])
plt.show()
